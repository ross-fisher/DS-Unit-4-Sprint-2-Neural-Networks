# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten()) #input layer
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax)) #softmax for a probability distribution

# %%
x_train = x_train[0:10000]
y_train = y_train[0:10000]

# %%
model.compile(optimer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=3)
# Out:
# Train on 10000 samples
# Epoch 1/3
# 10000/10000 [==============================] - 1s 121us/sample - loss: 0.5303 - accuracy: 0.8562
# Epoch 2/3
# 10000/10000 [==============================] - 1s 64us/sample - loss: 0.2434 - accuracy: 0.9274
# Epoch 3/3
# 10000/10000 [==============================] - 1s 64us/sample - loss: 0.1745 - accuracy: 0.9465

# %%
import tensorflow as tf


# save model
# model.save('num_reader.model')

#tf.get_logger().setLevel('INFO')
# Can also be set using the AUTOGRAPH_VERBOSITY environment variable
tf.autograph.set_verbosity(0)
import os
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # or any {'0', '1', '2'}

predictions = model.predict([x_test])

# %%
predictions.shape
# Out:
# (10000, 10)

# %%
import numpy as np
np.argmax(predictions[0])
# Out:
# 7

# %%
import matplotlib.pyplot as plt

plt.imshow(x_test[0], cmap='binary')

# %%
# check model validity
val_loss, val_acc = model.evaluate(x_test, y_test);
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
